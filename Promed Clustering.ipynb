# %% [markdown]
# # Import libraries

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler
from geopy.distance import great_circle
from shapely.geometry import MultiPoint
from pymongo import MongoClient
import calendar

# %% [markdown]
# # setup database

# %%
client = MongoClient('localhost', 27017)
db = client['promed']
posts = db.posts

# %% [markdown]
# # Functions

# %%
# Gets a unique list of diseases
def get_disease_list():
#   diseaseNames = posts.distinct('subject.diseaseLabels')
#   return sorted(diseaseNames)
    return ['Anthrax']

# %%
# Get all the articles that have the current disease in it's "diseaseLabels" array
def get_articles(disease):
#   print('get articles', disease)
  articles = posts.find({ 
    'zoomLat': {'$ne': None}, 
    'zoomLon': {'$ne': None}, 
    'subject.diseaseLabels':{'$not':{'$size': 0}}, 
    'subject.diseaseLabels': {'$in': [disease]}
    },
    {'subject.diseaseLabels':1,
    'zoomLat': 1, 
    'zoomLon': 1, 
    'sourceDate': 1, 
    'promedDate': 1}
  ).limit(100)
  articles = list(articles);
  for article in articles:
    try:
        # not all articles have a sourceDate so fall back to promedDate if missing.
        date = article.get('sourceDate') or article.get('promedDate')
        # convert date object to timestamp so DBSCAN can handle it
        article['sourceDate'] = calendar.timegm(date.timetuple())/10000000.0
        # convert disease labels array to single disease name
        article['subject'] = article['subject']['diseaseLabels'][0]
        article['zoomLat'] = float(article['zoomLat'])
        article['zoomLon'] = float(article['zoomLon'])
    except Exception as e:
        print("Problem parsing article:", article)
        print(e)
        raise
#   print(sorted([x['sourceDate'] for x in articles]))

  return articles

# %% [markdown]
# # Single step clustering on timestamp/lat/long

# %% [markdown]
# ### Questions:
# How do I determine the optimal `eps` value here?
#
# How should I take into account the third dimension (timestamp) when determining the `eps` value?  When it was only lat long the values were in similar ranges (-90 -> 90 and -180 -> 180) but with the timestamp values are much larger (ex: `9433152000`) which makes me thing that you will never get two timestamps in the same neighborhood if you have and eps value of, say, 2.  If I begin dividing the timestamp value by 10,000,000 it goes into a similar range for lat/long - is this something I should consider doing?
#
# Is it possible to specify dimensions for a sphereoid to define the `eps`?  It seems like there are a lot of situations where you wouldn't want a perfectly simetrical shape defining the neighborhood.
#
# How would I go about visualizing 3d data?  4d?

# %%
def cluster(data, fields, eps=2):
#     print(type(data))
    if type(data) is not np.ndarray:
#         print('convert....')
        data = data.as_matrix(columns=fields)
#     print(type(data))
    #   coordinates = df.as_matrix(columns=['zoomLon', 'zoomLat'])
    dbsc = DBSCAN(eps=eps, min_samples=1, algorithm='ball_tree').fit(data)
    core_samples_mask = np.zeros_like(dbsc.labels_, dtype=bool)
    core_samples_mask[dbsc.core_sample_indices_] = True
    cluster_labels = dbsc.labels_
    num_clusters = len(set(cluster_labels)) - (1 if -1 in cluster_labels else 0)
    clusters = pd.Series([data[cluster_labels == n] for n in range(num_clusters)])
#     print('Number of clusters: {}'.format(num_clusters))
#     for cluster in clusters:
#         print(cluster[:])
#     print('***********')
    return clusters

# %%
def distance_cluster(data, fields):
    kms_per_radian = 6371.0088
    eps = 1.5 / kms_per_radian
    print("distance data:")
    print(np.radians(data[fields]))
    dbsc = DBSCAN(eps=eps, min_samples=1, algorithm='ball_tree', metric='haversine').fit(np.radians(data[fields]))
    core_samples_mask = np.zeros_like(dbsc.labels_, dtype=bool)
    core_samples_mask[dbsc.core_sample_indices_] = True
    cluster_labels = dbsc.labels_
    num_clusters = len(set(cluster_labels)) - (1 if -1 in cluster_labels else 0)
    clusters = pd.Series([data[cluster_labels == n] for n in range(num_clusters)])
    return clusters

# %%
def cluster_single_step(df):
    cluster(df,['zoomLon', 'zoomLat', 'sourceDate'])

# %% [markdown]
# # Two step temporal/spatial clustering
# First cluster on times only.  After that cluster on lat/long great circle distances

# %%
def cluster_two_step(df):
    # perform temporal clustering
    temporalClusters = cluster(df,['sourceDate'], .1) # eps of .1 ~ 8 days
#     print(type(temporalClusters))
    # foreach temporal cluster
    for temporalCluster in temporalClusters:
        subSet = df['sourceDate'].isin(temporalCluster.flatten())
#         print("articles in that temporal cluster:")
#         print(df.loc[subSet][['subject','sourceDate','zoomLat','zoomLon']])
        clusterArticles = df.loc[subSet][['sourceDate','zoomLat','zoomLon']]
#         print('clusterArticles')
#         print(clusterArticles)
#         perform clustering on the articles in that cluster based on the lat/long great circle distance
        spacialTemporalCluster = distance_cluster(clusterArticles, ['zoomLat', 'zoomLon']) 
#         print('temporal cluster*******************************')
#         print(temporalCluster.flatten())
        print('spatial/temporal cluster***********************', len(spacialTemporalCluster[:].values))
#         print(spacialTemporalCluster[['sourceDate', 'zoomLat', 'zoomLon']])
        print(spacialTemporalCluster[:].values)
        print()
        print()

# %% [markdown]
# # Process articles

# %%
diseaseList = get_disease_list()
# for each disease get a list of articles and cluster them
for disease in diseaseList:
    articleList = list(get_articles(disease))
    print("{0} articles for {1}".format(len(articleList), disease))
    df = pd.DataFrame(articleList)
    cluster_single_step(df)
    cluster_two_step(df)
# Out:
# 100 articles for Anthrax
# distance data:
#     zoomLat   zoomLon
# 0  0.850107  0.340193
# 1  0.858739  0.377901
# spatial/temporal cluster*********************** 2
# [   sourceDate    zoomLat   zoomLon
# 0   135.27648  48.707531  19.49165
#     sourceDate   zoomLat    zoomLon
# 1   135.27648  49.20211  21.652161]
#
#
# distance data:
#     zoomLat   zoomLon
# 2  0.416662  2.112145
# 6  0.150556  0.691430
# spatial/temporal cluster*********************** 2
# [   sourceDate    zoomLat     zoomLon
# 2   94.400886  23.873001  121.016998
#     sourceDate  zoomLat    zoomLon
# 6   94.408869  8.62622  39.616032]
#
#
# distance data:
#     zoomLat   zoomLon
# 3  1.081164  1.633239
# spatial/temporal cluster*********************** 1
# [   sourceDate   zoomLat   zoomLon
# 3    80.78305  61.94614  93.57769]
#
#
# distance data:
#     zoomLat   zoomLon
# 4  0.576797  0.763968
# 7  0.576797  0.763968
# 8  0.576797  0.763968
# spatial/temporal cluster*********************** 1
# [    sourceDate    zoomLat    zoomLon
# 4   80.982234  33.048031  43.772129
# 7   80.904960  33.048031  43.772129
# 8   80.913600  33.048031  43.772129]
#
#
# distance data:
#      zoomLat   zoomLon
# 5   0.731752  0.759523
# 9   0.731752  0.759523
# 10  0.706858  0.829031
# spatial/temporal cluster*********************** 2
# [    sourceDate    zoomLat    zoomLon
# 5   81.449220  41.926311  43.517448
# 9   81.439487  41.926311  43.517448
#      sourceDate  zoomLat  zoomLon
# 10   81.482903     40.5     47.5]
#
#
# distance data:
#      zoomLat   zoomLon
# 11  1.081164  1.633239
# spatial/temporal cluster*********************** 1
# [    sourceDate   zoomLat   zoomLon
# 11   83.710131  61.94614  93.57769]
#
#
# distance data:
#      zoomLat   zoomLon
# 12 -0.046003  2.110758
# 14 -0.046003  2.110758
# spatial/temporal cluster*********************** 1
# [     sourceDate  zoomLat   zoomLon
# 12     83.8857  -2.6358  120.9375
# 14     83.9289  -2.6358  120.9375]
#
#
# distance data:
#      zoomLat   zoomLon
# 13  1.081164  1.633239
# 15  1.081164  1.633239
# spatial/temporal cluster*********************** 1
# [     sourceDate   zoomLat   zoomLon
# 13   84.671940  61.94614  93.57769
# 15   84.651085  61.94614  93.57769]
#
#
# distance data:
#      zoomLat   zoomLon
# 16  0.264017  1.763085
# 17  0.264017  1.763085
# 18 -0.645512  2.531068
# 19 -0.645512  2.531068
# 20  0.264017  1.763085
# 21 -0.645512  2.531068
# 22 -0.645512  2.531068
# 23 -0.645512  2.531068
# 24 -0.645512  2.531068
# 37 -0.645512  2.531068
# 38 -0.645512  2.531068
# 70 -0.104720  0.610865
# spatial/temporal cluster*********************** 3
# [     sourceDate   zoomLat     zoomLon
# 16   85.559674  15.12704  101.017357
# 17   85.568007  15.12704  101.017357
# 20   85.585403  15.12704  101.017357
#      sourceDate  zoomLat     zoomLon
# 18   85.566806 -36.9851  145.019501
# 19   85.575793 -36.9851  145.019501
# 21   85.594196 -36.9851  145.019501
# 22   85.570560 -36.9851  145.019501
# 23   85.602003 -36.9851  145.019501
# 24   85.717380 -36.9851  145.019501
# 37   85.626301 -36.9851  145.019501
# 38   85.658570 -36.9851  145.019501
#      sourceDate  zoomLat  zoomLon
# 70    85.78656     -6.0     35.0]
#
#
# distance data:
#      zoomLat   zoomLon
# 25  0.138926 -0.021071
# 26  0.138926 -0.021071
# 27  0.138926 -0.021071
# 28  0.855510  0.547808
# 29  0.855510  0.547808
# 30  0.138926 -0.021071
# 31  0.138926 -0.021071
# 33  0.855510  0.547808
# 34  0.855510  0.547808
# 35 -0.645512  2.531068
# 36  0.138926 -0.021071
# spatial/temporal cluster*********************** 3
# [     sourceDate  zoomLat  zoomLon
# 25   86.417220  7.95985  -1.2073
# 26   86.421172  7.95985  -1.2073
# 27   86.425920  7.95985  -1.2073
# 30   86.451780  7.95985  -1.2073
# 31   86.451780  7.95985  -1.2073
# 36   86.546880  7.95985  -1.2073
#      sourceDate   zoomLat   zoomLon
# 28   86.437395  49.01709  31.38711
# 29   86.434560  49.01709  31.38711
# 33   86.449035  49.01709  31.38711
# 34   86.512320  49.01709  31.38711
#      sourceDate  zoomLat     zoomLon
# 35    86.53818 -36.9851  145.019501]
#
#
# distance data:
#      zoomLat   zoomLon
# 32  0.138926 -0.021071
# spatial/temporal cluster*********************** 1
# [    sourceDate  zoomLat  zoomLon
# 32    86.19264  7.95985  -1.2073]
#
#
# distance data:
#     zoomLat   zoomLon
# 39  0.85551  0.547808
# spatial/temporal cluster*********************** 1
# [    sourceDate   zoomLat   zoomLon
# 39     86.7024  49.01709  31.38711]
#
#
# distance data:
#     zoomLat   zoomLon
# 40  0.76062 -1.474156
# 41  0.76062 -1.474156
# 44  0.76062 -1.474156
# spatial/temporal cluster*********************** 1
# [     sourceDate    zoomLat    zoomLon
# 40   86.948815  43.580299 -84.462898
# 41   86.959009  43.580299 -84.462898
# 44   86.961510  43.580299 -84.462898]
#
#
# distance data:
#      zoomLat   zoomLon
# 42 -0.331614  0.521362
# 43  0.776610 -1.749506
# 46  0.991782  0.779262
# 47  0.986111 -0.069813
# 48  0.986111 -0.069813
# 49  0.545473  0.642050
# 52 -0.386298  0.300516
# 53  0.986111 -0.069813
# spatial/temporal cluster*********************** 6
# [    sourceDate    zoomLat   zoomLon
# 42    87.20352 -19.000099  29.87184
#      sourceDate    zoomLat     zoomLon
# 43    87.20352  44.496498 -100.239304
#      sourceDate    zoomLat    zoomLon
# 46    87.20352  56.824932  44.648438
#      sourceDate  zoomLat  zoomLon
# 47   87.203520     56.5     -4.0
# 48   87.260759     56.5     -4.0
# 53   87.341760     56.5     -4.0
#      sourceDate    zoomLat    zoomLon
# 49     87.2208  31.253321  36.786732
#      sourceDate    zoomLat    zoomLon
# 52   87.302315 -22.133249  17.218281]
#
#
# distance data:
#      zoomLat   zoomLon
# 45  0.545257 -1.731866
# spatial/temporal cluster*********************** 1
# [    sourceDate  zoomLat  zoomLon
# 45   87.072725  31.2409 -99.2286]
#
#
# distance data:
#      zoomLat   zoomLon
# 50  0.838037  1.163398
# 51  0.545257 -1.731866
# 54  0.601936 -1.849981
# spatial/temporal cluster*********************** 3
# [    sourceDate    zoomLat    zoomLon
# 50   87.461138  48.015991  66.657822
#      sourceDate  zoomLat  zoomLon
# 51   87.468029  31.2409 -99.2286
#      sourceDate  zoomLat     zoomLon
# 54    87.46272  34.4884 -105.996101]
#
#
# distance data:
#      zoomLat   zoomLon
# 55  0.601936 -1.849981
# spatial/temporal cluster*********************** 1
# [    sourceDate  zoomLat     zoomLon
# 55    87.65274  34.4884 -105.996101]
#
#
# distance data:
#      zoomLat   zoomLon
# 56 -0.243526  0.485171
# spatial/temporal cluster*********************** 1
# [    sourceDate   zoomLat   zoomLon
# 56    88.08575 -13.95302  27.79825]
#
#
# distance data:
#      zoomLat   zoomLon
# 57  0.601936 -1.849981
# spatial/temporal cluster*********************** 1
# [    sourceDate  zoomLat     zoomLon
# 57   88.274493  34.4884 -105.996101]
#
#
# distance data:
#      zoomLat   zoomLon
# 58  1.012026  1.081455
# 60  1.081164  1.633239
# 61  0.697555 -1.702675
# 62  1.081164  1.633239
# 63  0.697555 -1.702675
# 64  0.697555 -1.702675
# 65  0.697555 -1.702675
# 66  0.678846 -1.344544
# 71  0.545257 -1.731866
# 72 -0.046003  2.110758
# spatial/temporal cluster*********************** 6
# [    sourceDate    zoomLat    zoomLon
# 58   88.661621  57.984798  61.962799
#      sourceDate   zoomLat   zoomLon
# 60   88.758422  61.94614  93.57769
# 62   88.811169  61.94614  93.57769
#      sourceDate   zoomLat    zoomLon
# 61   88.793073  39.96693 -97.556099
# 63   88.819121  39.96693 -97.556099
# 64   88.858141  39.96693 -97.556099
# 65   88.903620  39.96693 -97.556099
#      sourceDate  zoomLat    zoomLon
# 66   88.948151   38.895 -77.036697
#      sourceDate  zoomLat  zoomLon
# 71   88.947708  31.2409 -99.2286
#      sourceDate  zoomLat   zoomLon
# 72    88.97472  -2.6358  120.9375]
#
#
# distance data:
#      zoomLat   zoomLon
# 59  0.697555 -1.702675
# spatial/temporal cluster*********************** 1
# [    sourceDate   zoomLat    zoomLon
# 59   88.377304  39.96693 -97.556099]
#
#
# distance data:
#      zoomLat   zoomLon
# 67  0.697555 -1.702675
# 68  0.697555 -1.702675
# 69  0.697555 -1.702675
# 74  0.697555 -1.702675
# 75  1.081164  1.633239
# 76  0.950681 -0.035282
# 77  0.691168 -0.140721
# 78  0.697555 -1.702675
# spatial/temporal cluster*********************** 4
# [     sourceDate   zoomLat    zoomLon
# 67   89.218191  39.96693 -97.556099
# 68   89.265438  39.96693 -97.556099
# 69   89.269752  39.96693 -97.556099
# 74   89.094327  39.96693 -97.556099
# 78   89.186706  39.96693 -97.556099
#      sourceDate   zoomLat   zoomLon
# 75   89.129017  61.94614  93.57769
#      sourceDate    zoomLat  zoomLon
# 76   89.172677  54.470001  -2.0215
#      sourceDate   zoomLat  zoomLon
# 77   89.133843  39.60099 -8.06274]
#
#
# distance data:
#      zoomLat   zoomLon
# 73  0.650139 -2.090037
# 79  0.697555 -1.702675
# 80  0.264017  1.763085
# 81  0.697555 -1.702675
# 82  0.697555 -1.702675
# spatial/temporal cluster*********************** 3
# [     sourceDate    zoomLat     zoomLon
# 73   89.399032  37.250198 -119.750298
#      sourceDate   zoomLat    zoomLon
# 79   89.433489  39.96693 -97.556099
# 81   89.587915  39.96693 -97.556099
# 82   89.559283  39.96693 -97.556099
#      sourceDate   zoomLat     zoomLon
# 80    89.48906  15.12704  101.017357]
#
#
# distance data:
#      zoomLat   zoomLon
# 83  0.697555 -1.702675
# 84  0.838037  1.163398
# 87  0.959980 -1.692749
# 88  0.723702  1.301241
# 89  0.797455  0.695180
# 90  0.672444  1.239917
# 91  0.672444  1.239917
# 92  1.081164  1.633239
# 93  0.838037  1.163398
# 94  0.838037  1.163398
# 95 -0.407047  2.512660
# 96 -0.407047  2.512660
# 97  0.838037  1.163398
# 98  0.828813 -1.745671
# 99  0.797455  0.695180
# spatial/temporal cluster*********************** 9
# [    sourceDate   zoomLat    zoomLon
# 83   89.993856  39.96693 -97.556099
#      sourceDate    zoomLat    zoomLon
# 84   90.054660  48.015991  66.657822
# 93   90.120482  48.015991  66.657822
# 94   90.120858  48.015991  66.657822
# 97   90.129585  48.015991  66.657822
#      sourceDate  zoomLat    zoomLon
# 87    90.22664  55.0028 -96.987396
#      sourceDate   zoomLat    zoomLon
# 88   90.235523  41.46505  74.555603
#      sourceDate  zoomLat    zoomLon
# 89   90.233480  45.6908  39.830898
# 99   90.155042  45.6908  39.830898
#      sourceDate    zoomLat  zoomLon
# 90   90.235694  38.528179   71.042
# 91   90.232842  38.528179   71.042
#      sourceDate   zoomLat   zoomLon
# 92   90.109768  61.94614  93.57769
#      sourceDate  zoomLat     zoomLon
# 95   90.240994 -23.3221  143.964798
# 96   90.250131 -23.3221  143.964798
#      sourceDate    zoomLat   zoomLon
# 98   90.154995  47.487499 -100.0196]
#
#
# distance data:
#      zoomLat   zoomLon
# 85  0.697555 -1.702675
# 86  0.950681 -0.035282
# spatial/temporal cluster*********************** 2
# [    sourceDate   zoomLat    zoomLon
# 85   89.709469  39.96693 -97.556099
#      sourceDate    zoomLat  zoomLon
# 86   89.731974  54.470001  -2.0215]

# %% [markdown]
# # Questions:
# What would be the next steps?  How do we determine which cluster future articles fall into?  Do I just re-run this with all the data?
