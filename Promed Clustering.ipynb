# %% [markdown]
# # Import libraries

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler
from geopy.distance import great_circle
from shapely.geometry import MultiPoint
from pymongo import MongoClient
import calendar

# %% [markdown]
# # setup database

# %%
client = MongoClient('localhost', 27017)
db = client['promed']
posts = db.posts

# %% [markdown]
# # Functions

# %%
# Gets a unique list of diseases
def get_disease_list():
#   diseaseNames = posts.distinct('subject.diseaseLabels')
#   return sorted(diseaseNames)
    return ['Anthrax']

# %%
# Get all the articles that have the current disease in it's "diseaseLabels" array
def get_articles(disease):
#   print('get articles', disease)
  articles = posts.find({ 
    'zoomLat': {'$ne': None}, 
    'zoomLon': {'$ne': None}, 
    'subject.diseaseLabels':{'$not':{'$size': 0}}, 
    'subject.diseaseLabels': {'$in': [disease]}
    },
    {'subject.diseaseLabels':1,
    'zoomLat': 1, 
    'zoomLon': 1, 
    'sourceDate': 1, 
    'promedDate': 1}
  ).limit(100)
  articles = list(articles);
  for article in articles:
    try:
        # not all articles have a sourceDate so fall back to promedDate if missing.
        date = article.get('sourceDate') or article.get('promedDate')
        # convert date object to timestamp so DBSCAN can handle it
        article['sourceDate'] = calendar.timegm(date.timetuple())/10000000.0
        # convert disease labels array to single disease name
        article['subject'] = article['subject']['diseaseLabels'][0]
        article['zoomLat'] = float(article['zoomLat'])
        article['zoomLon'] = float(article['zoomLon'])
    except Exception as e:
        print("Problem parsing article:", article)
        print(e)
        raise
#   print(sorted([x['sourceDate'] for x in articles]))

  return articles

# %% [markdown]
# # Single step clustering on timestamp/lat/long

# %% [markdown]
# ### Questions:
# How do I determine the optimal `eps` value here?
#
# How should I take into account the third dimension (timestamp) when determining the `eps` value?  When it was only lat long the values were in similar ranges (-90 -> 90 and -180 -> 180) but with the timestamp values are much larger (ex: `9433152000`) which makes me thing that you will never get two timestamps in the same neighborhood if you have and eps value of, say, 2.  If I begin dividing the timestamp value by 10,000,000 it goes into a similar range for lat/long - is this something I should consider doing?
#
# Is it possible to specify dimensions for a sphereoid to define the `eps`?  It seems like there are a lot of situations where you wouldn't want a perfectly simetrical shape defining the neighborhood.
#
# How would I go about visualizing 3d data?  4d?

# %%
def cluster(data, fields, eps=2):
#     print(type(data))
    if type(data) is not np.ndarray:
#         print('convert....')
        data = data.as_matrix(columns=fields)
#     print(type(data))
    #   coordinates = df.as_matrix(columns=['zoomLon', 'zoomLat'])
    dbsc = DBSCAN(eps=eps, min_samples=1, algorithm='ball_tree').fit(data)
    core_samples_mask = np.zeros_like(dbsc.labels_, dtype=bool)
    core_samples_mask[dbsc.core_sample_indices_] = True
    cluster_labels = dbsc.labels_
    num_clusters = len(set(cluster_labels)) - (1 if -1 in cluster_labels else 0)
    clusters = pd.Series([data[cluster_labels == n] for n in range(num_clusters)])
#     print('Number of clusters: {}'.format(num_clusters))
#     for cluster in clusters:
#         print(cluster[:])
#     print('***********')
    return clusters

# %%
def distance_cluster(data, fields):
    kms_per_radian = 6371.0088
    eps = 1.5 / kms_per_radian
    print("distance data:")
    print(data[fields])
    dbsc = DBSCAN(eps=eps, min_samples=1, algorithm='ball_tree', metric='haversine').fit(data[fields])
    core_samples_mask = np.zeros_like(dbsc.labels_, dtype=bool)
    core_samples_mask[dbsc.core_sample_indices_] = True
    cluster_labels = dbsc.labels_
    num_clusters = len(set(cluster_labels)) - (1 if -1 in cluster_labels else 0)
    clusters = pd.Series([data[cluster_labels == n] for n in range(num_clusters)])
    return clusters

# %%
def cluster_single_step(df):
    cluster(df,['zoomLon', 'zoomLat', 'sourceDate'])

# %% [markdown]
# # Two step temporal/spatial clustering
# First cluster on times only.  After that cluster on lat/long great circle distances

# %%
def cluster_two_step(df):
    # perform temporal clustering
    temporalClusters = cluster(df,['sourceDate'], .1) # eps of .1 ~ 8 days
#     print(type(temporalClusters))
    # foreach temporal cluster
    for temporalCluster in temporalClusters:
        subSet = df['sourceDate'].isin(temporalCluster.flatten())
#         print("articles in that temporal cluster:")
#         print(df.loc[subSet][['subject','sourceDate','zoomLat','zoomLon']])
        clusterArticles = df.loc[subSet][['sourceDate','zoomLat','zoomLon']]
        print('clusterArticles')
        print(clusterArticles)
#         perform clustering on the articles in that cluster based on the lat/long great circle distance
        spacialTemporalCluster = distance_cluster(clusterArticles, ['zoomLat', 'zoomLon']) 
        print('temporal cluster*******************************')
        print(temporalCluster.flatten())
        print('spatial/temporal cluster***********************')
#         print(spacialTemporalCluster[['sourceDate', 'zoomLat', 'zoomLon']])
        print(spacialTemporalCluster[:].values)
        print()
        print()

# %% [markdown]
# # Process articles

# %%
diseaseList = get_disease_list()
# for each disease get a list of articles and cluster them
for disease in diseaseList:
    articleList = list(get_articles(disease))
    print("{0} articles for {1}".format(len(articleList), disease))
    df = pd.DataFrame(articleList)
    cluster_single_step(df)
    cluster_two_step(df)
# Out:
# 100 articles for Anthrax
# clusterArticles
#    sourceDate    zoomLat    zoomLon
# 0   135.27648  48.707531  19.491650
# 1   135.27648  49.202110  21.652161
# distance data:
#      zoomLat    zoomLon
# 0  48.707531  19.491650
# 1  49.202110  21.652161
# temporal cluster*******************************
# [ 135.27648  135.27648]
# spatial/temporal cluster***********************
# [   sourceDate    zoomLat   zoomLon
# 0   135.27648  48.707531  19.49165
#     sourceDate   zoomLat    zoomLon
# 1   135.27648  49.20211  21.652161]
#
#
# clusterArticles
#    sourceDate    zoomLat     zoomLon
# 2   94.400886  23.873001  121.016998
# 6   94.408869   8.626220   39.616032
# distance data:
#      zoomLat     zoomLon
# 2  23.873001  121.016998
# 6   8.626220   39.616032
# temporal cluster*******************************
# [ 94.4008859  94.4088692]
# spatial/temporal cluster***********************
# [   sourceDate    zoomLat     zoomLon
# 2   94.400886  23.873001  121.016998
#     sourceDate  zoomLat    zoomLon
# 6   94.408869  8.62622  39.616032]
#
#
# clusterArticles
#    sourceDate   zoomLat   zoomLon
# 3    80.78305  61.94614  93.57769
# distance data:
#     zoomLat   zoomLon
# 3  61.94614  93.57769
# temporal cluster*******************************
# [ 80.78305]
# spatial/temporal cluster***********************
# [   sourceDate   zoomLat   zoomLon
# 3    80.78305  61.94614  93.57769]
#
#
# clusterArticles
#    sourceDate    zoomLat    zoomLon
# 4   80.982234  33.048031  43.772129
# 7   80.904960  33.048031  43.772129
# 8   80.913600  33.048031  43.772129
# distance data:
#      zoomLat    zoomLon
# 4  33.048031  43.772129
# 7  33.048031  43.772129
# 8  33.048031  43.772129
# temporal cluster*******************************
# [ 80.9822341  80.90496    80.9136   ]
# spatial/temporal cluster***********************
# [    sourceDate    zoomLat    zoomLon
# 4   80.982234  33.048031  43.772129
# 7   80.904960  33.048031  43.772129
# 8   80.913600  33.048031  43.772129]
#
#
# clusterArticles
#     sourceDate    zoomLat    zoomLon
# 5    81.449220  41.926311  43.517448
# 9    81.439487  41.926311  43.517448
# 10   81.482903  40.500000  47.500000
# distance data:
#       zoomLat    zoomLon
# 5   41.926311  43.517448
# 9   41.926311  43.517448
# 10  40.500000  47.500000
# temporal cluster*******************************
# [ 81.44922    81.4394869  81.4829029]
# spatial/temporal cluster***********************
# [    sourceDate    zoomLat    zoomLon
# 5   81.449220  41.926311  43.517448
# 9   81.439487  41.926311  43.517448
#      sourceDate  zoomLat  zoomLon
# 10   81.482903     40.5     47.5]
#
#
# clusterArticles
#     sourceDate   zoomLat   zoomLon
# 11   83.710131  61.94614  93.57769
# distance data:
#      zoomLat   zoomLon
# 11  61.94614  93.57769
# temporal cluster*******************************
# [ 83.7101314]
# spatial/temporal cluster***********************
# [    sourceDate   zoomLat   zoomLon
# 11   83.710131  61.94614  93.57769]
#
#
# clusterArticles
#     sourceDate  zoomLat   zoomLon
# 12     83.8857  -2.6358  120.9375
# 14     83.9289  -2.6358  120.9375
# distance data:
#     zoomLat   zoomLon
# 12  -2.6358  120.9375
# 14  -2.6358  120.9375
# temporal cluster*******************************
# [ 83.8857  83.9289]
# spatial/temporal cluster***********************
# [     sourceDate  zoomLat   zoomLon
# 12     83.8857  -2.6358  120.9375
# 14     83.9289  -2.6358  120.9375]
#
#
# clusterArticles
#     sourceDate   zoomLat   zoomLon
# 13   84.671940  61.94614  93.57769
# 15   84.651085  61.94614  93.57769
# distance data:
#      zoomLat   zoomLon
# 13  61.94614  93.57769
# 15  61.94614  93.57769
# temporal cluster*******************************
# [ 84.67194    84.6510846]
# spatial/temporal cluster***********************
# [     sourceDate   zoomLat   zoomLon
# 13   84.671940  61.94614  93.57769
# 15   84.651085  61.94614  93.57769]
#
#
# clusterArticles
#     sourceDate   zoomLat     zoomLon
# 16   85.559674  15.12704  101.017357
# 17   85.568007  15.12704  101.017357
# 18   85.566806 -36.98510  145.019501
# 19   85.575793 -36.98510  145.019501
# 20   85.585403  15.12704  101.017357
# 21   85.594196 -36.98510  145.019501
# 22   85.570560 -36.98510  145.019501
# 23   85.602003 -36.98510  145.019501
# 24   85.717380 -36.98510  145.019501
# 37   85.626301 -36.98510  145.019501
# 38   85.658570 -36.98510  145.019501
# 70   85.786560  -6.00000   35.000000
# distance data:
#      zoomLat     zoomLon
# 16  15.12704  101.017357
# 17  15.12704  101.017357
# 18 -36.98510  145.019501
# 19 -36.98510  145.019501
# 20  15.12704  101.017357
# 21 -36.98510  145.019501
# 22 -36.98510  145.019501
# 23 -36.98510  145.019501
# 24 -36.98510  145.019501
# 37 -36.98510  145.019501
# 38 -36.98510  145.019501
# 70  -6.00000   35.000000
# temporal cluster*******************************
# [ 85.5596745  85.568007   85.5668055  85.5757925  85.5854032  85.594196
#   85.57056    85.602003   85.71738    85.6263015  85.6585705  85.78656  ]
# spatial/temporal cluster***********************
# [     sourceDate   zoomLat     zoomLon
# 16   85.559674  15.12704  101.017357
# 17   85.568007  15.12704  101.017357
# 20   85.585403  15.12704  101.017357
#      sourceDate  zoomLat     zoomLon
# 18   85.566806 -36.9851  145.019501
# 19   85.575793 -36.9851  145.019501
# 21   85.594196 -36.9851  145.019501
# 22   85.570560 -36.9851  145.019501
# 23   85.602003 -36.9851  145.019501
# 24   85.717380 -36.9851  145.019501
# 37   85.626301 -36.9851  145.019501
# 38   85.658570 -36.9851  145.019501
#      sourceDate  zoomLat  zoomLon
# 70    85.78656     -6.0     35.0]
#
#
# clusterArticles
#     sourceDate   zoomLat     zoomLon
# 25   86.417220   7.95985   -1.207300
# 26   86.421172   7.95985   -1.207300
# 27   86.425920   7.95985   -1.207300
# 28   86.437395  49.01709   31.387110
# 29   86.434560  49.01709   31.387110
# 30   86.451780   7.95985   -1.207300
# 31   86.451780   7.95985   -1.207300
# 33   86.449035  49.01709   31.387110
# 34   86.512320  49.01709   31.387110
# 35   86.538180 -36.98510  145.019501
# 36   86.546880   7.95985   -1.207300
# distance data:
#      zoomLat     zoomLon
# 25   7.95985   -1.207300
# 26   7.95985   -1.207300
# 27   7.95985   -1.207300
# 28  49.01709   31.387110
# 29  49.01709   31.387110
# 30   7.95985   -1.207300
# 31   7.95985   -1.207300
# 33  49.01709   31.387110
# 34  49.01709   31.387110
# 35 -36.98510  145.019501
# 36   7.95985   -1.207300
# temporal cluster*******************************
# [ 86.41722    86.4211718  86.42592    86.4373953  86.43456    86.45178
#   86.45178    86.4490352  86.51232    86.53818    86.54688  ]
# spatial/temporal cluster***********************
# [     sourceDate  zoomLat  zoomLon
# 25   86.417220  7.95985  -1.2073
# 26   86.421172  7.95985  -1.2073
# 27   86.425920  7.95985  -1.2073
# 30   86.451780  7.95985  -1.2073
# 31   86.451780  7.95985  -1.2073
# 36   86.546880  7.95985  -1.2073
#      sourceDate   zoomLat   zoomLon
# 28   86.437395  49.01709  31.38711
# 29   86.434560  49.01709  31.38711
# 33   86.449035  49.01709  31.38711
# 34   86.512320  49.01709  31.38711
#      sourceDate  zoomLat     zoomLon
# 35    86.53818 -36.9851  145.019501]
#
#
# clusterArticles
#     sourceDate  zoomLat  zoomLon
# 32    86.19264  7.95985  -1.2073
# distance data:
#     zoomLat  zoomLon
# 32  7.95985  -1.2073
# temporal cluster*******************************
# [ 86.19264]
# spatial/temporal cluster***********************
# [    sourceDate  zoomLat  zoomLon
# 32    86.19264  7.95985  -1.2073]
#
#
# clusterArticles
#     sourceDate   zoomLat   zoomLon
# 39     86.7024  49.01709  31.38711
# distance data:
#      zoomLat   zoomLon
# 39  49.01709  31.38711
# temporal cluster*******************************
# [ 86.7024]
# spatial/temporal cluster***********************
# [    sourceDate   zoomLat   zoomLon
# 39     86.7024  49.01709  31.38711]
#
#
# clusterArticles
#     sourceDate    zoomLat    zoomLon
# 40   86.948815  43.580299 -84.462898
# 41   86.959009  43.580299 -84.462898
# 44   86.961510  43.580299 -84.462898
# distance data:
#       zoomLat    zoomLon
# 40  43.580299 -84.462898
# 41  43.580299 -84.462898
# 44  43.580299 -84.462898
# temporal cluster*******************************
# [ 86.9488152  86.9590095  86.9615101]
# spatial/temporal cluster***********************
# [     sourceDate    zoomLat    zoomLon
# 40   86.948815  43.580299 -84.462898
# 41   86.959009  43.580299 -84.462898
# 44   86.961510  43.580299 -84.462898]
#
#
# clusterArticles
#     sourceDate    zoomLat     zoomLon
# 42   87.203520 -19.000099   29.871840
# 43   87.203520  44.496498 -100.239304
# 46   87.203520  56.824932   44.648438
# 47   87.203520  56.500000   -4.000000
# 48   87.260759  56.500000   -4.000000
# 49   87.220800  31.253321   36.786732
# 52   87.302315 -22.133249   17.218281
# 53   87.341760  56.500000   -4.000000
# distance data:
#       zoomLat     zoomLon
# 42 -19.000099   29.871840
# 43  44.496498 -100.239304
# 46  56.824932   44.648438
# 47  56.500000   -4.000000
# 48  56.500000   -4.000000
# 49  31.253321   36.786732
# 52 -22.133249   17.218281
# 53  56.500000   -4.000000
# temporal cluster*******************************
# [ 87.20352    87.20352    87.20352    87.20352    87.2607594  87.2208
#   87.3023146  87.34176  ]
# spatial/temporal cluster***********************
# [    sourceDate    zoomLat   zoomLon
# 42    87.20352 -19.000099  29.87184
#      sourceDate    zoomLat     zoomLon
# 43    87.20352  44.496498 -100.239304
#      sourceDate    zoomLat    zoomLon
# 46    87.20352  56.824932  44.648438
#      sourceDate  zoomLat  zoomLon
# 47   87.203520     56.5     -4.0
# 48   87.260759     56.5     -4.0
# 53   87.341760     56.5     -4.0
#      sourceDate    zoomLat    zoomLon
# 49     87.2208  31.253321  36.786732
#      sourceDate    zoomLat    zoomLon
# 52   87.302315 -22.133249  17.218281]
#
#
# clusterArticles
#     sourceDate  zoomLat  zoomLon
# 45   87.072725  31.2409 -99.2286
# distance data:
#     zoomLat  zoomLon
# 45  31.2409 -99.2286
# temporal cluster*******************************
# [ 87.0727249]
# spatial/temporal cluster***********************
# [    sourceDate  zoomLat  zoomLon
# 45   87.072725  31.2409 -99.2286]
#
#
# clusterArticles
#     sourceDate    zoomLat     zoomLon
# 50   87.461138  48.015991   66.657822
# 51   87.468029  31.240900  -99.228600
# 54   87.462720  34.488400 -105.996101
# distance data:
#       zoomLat     zoomLon
# 50  48.015991   66.657822
# 51  31.240900  -99.228600
# 54  34.488400 -105.996101
# temporal cluster*******************************
# [ 87.4611381  87.4680291  87.46272  ]
# spatial/temporal cluster***********************
# [    sourceDate    zoomLat    zoomLon
# 50   87.461138  48.015991  66.657822
#      sourceDate  zoomLat  zoomLon
# 51   87.468029  31.2409 -99.2286
#      sourceDate  zoomLat     zoomLon
# 54    87.46272  34.4884 -105.996101]
#
#
# clusterArticles
#     sourceDate  zoomLat     zoomLon
# 55    87.65274  34.4884 -105.996101
# distance data:
#     zoomLat     zoomLon
# 55  34.4884 -105.996101
# temporal cluster*******************************
# [ 87.65274]
# spatial/temporal cluster***********************
# [    sourceDate  zoomLat     zoomLon
# 55    87.65274  34.4884 -105.996101]
#
#
# clusterArticles
#     sourceDate   zoomLat   zoomLon
# 56    88.08575 -13.95302  27.79825
# distance data:
#      zoomLat   zoomLon
# 56 -13.95302  27.79825
# temporal cluster*******************************
# [ 88.0857501]
# spatial/temporal cluster***********************
# [    sourceDate   zoomLat   zoomLon
# 56    88.08575 -13.95302  27.79825]
#
#
# clusterArticles
#     sourceDate  zoomLat     zoomLon
# 57   88.274493  34.4884 -105.996101
# distance data:
#     zoomLat     zoomLon
# 57  34.4884 -105.996101
# temporal cluster*******************************
# [ 88.2744927]
# spatial/temporal cluster***********************
# [    sourceDate  zoomLat     zoomLon
# 57   88.274493  34.4884 -105.996101]
#
#
# clusterArticles
#     sourceDate    zoomLat     zoomLon
# 58   88.661621  57.984798   61.962799
# 60   88.758422  61.946140   93.577690
# 61   88.793073  39.966930  -97.556099
# 62   88.811169  61.946140   93.577690
# 63   88.819121  39.966930  -97.556099
# 64   88.858141  39.966930  -97.556099
# 65   88.903620  39.966930  -97.556099
# 66   88.948151  38.895000  -77.036697
# 71   88.947708  31.240900  -99.228600
# 72   88.974720  -2.635800  120.937500
# distance data:
#       zoomLat     zoomLon
# 58  57.984798   61.962799
# 60  61.946140   93.577690
# 61  39.966930  -97.556099
# 62  61.946140   93.577690
# 63  39.966930  -97.556099
# 64  39.966930  -97.556099
# 65  39.966930  -97.556099
# 66  38.895000  -77.036697
# 71  31.240900  -99.228600
# 72  -2.635800  120.937500
# temporal cluster*******************************
# [ 88.6616206  88.7584219  88.7930733  88.8111691  88.8191211  88.8581413
#   88.9036199  88.9481514  88.9477078  88.97472  ]
# spatial/temporal cluster***********************
# [    sourceDate    zoomLat    zoomLon
# 58   88.661621  57.984798  61.962799
#      sourceDate   zoomLat   zoomLon
# 60   88.758422  61.94614  93.57769
# 62   88.811169  61.94614  93.57769
#      sourceDate   zoomLat    zoomLon
# 61   88.793073  39.96693 -97.556099
# 63   88.819121  39.96693 -97.556099
# 64   88.858141  39.96693 -97.556099
# 65   88.903620  39.96693 -97.556099
#      sourceDate  zoomLat    zoomLon
# 66   88.948151   38.895 -77.036697
#      sourceDate  zoomLat  zoomLon
# 71   88.947708  31.2409 -99.2286
#      sourceDate  zoomLat   zoomLon
# 72    88.97472  -2.6358  120.9375]
#
#
# clusterArticles
#     sourceDate   zoomLat    zoomLon
# 59   88.377304  39.96693 -97.556099
# distance data:
#      zoomLat    zoomLon
# 59  39.96693 -97.556099
# temporal cluster*******************************
# [ 88.3773044]
# spatial/temporal cluster***********************
# [    sourceDate   zoomLat    zoomLon
# 59   88.377304  39.96693 -97.556099]
#
#
# clusterArticles
#     sourceDate    zoomLat    zoomLon
# 67   89.218191  39.966930 -97.556099
# 68   89.265438  39.966930 -97.556099
# 69   89.269752  39.966930 -97.556099
# 74   89.094327  39.966930 -97.556099
# 75   89.129017  61.946140  93.577690
# 76   89.172677  54.470001  -2.021500
# 77   89.133843  39.600990  -8.062740
# 78   89.186706  39.966930 -97.556099
# distance data:
#       zoomLat    zoomLon
# 67  39.966930 -97.556099
# 68  39.966930 -97.556099
# 69  39.966930 -97.556099
# 74  39.966930 -97.556099
# 75  61.946140  93.577690
# 76  54.470001  -2.021500
# 77  39.600990  -8.062740
# 78  39.966930 -97.556099
# temporal cluster*******************************
# [ 89.2181905  89.265438   89.2697519  89.0943274  89.1290173  89.1726768
#   89.1338434  89.186706 ]
# spatial/temporal cluster***********************
# [     sourceDate   zoomLat    zoomLon
# 67   89.218191  39.96693 -97.556099
# 68   89.265438  39.96693 -97.556099
# 69   89.269752  39.96693 -97.556099
# 74   89.094327  39.96693 -97.556099
# 78   89.186706  39.96693 -97.556099
#      sourceDate   zoomLat   zoomLon
# 75   89.129017  61.94614  93.57769
#      sourceDate    zoomLat  zoomLon
# 76   89.172677  54.470001  -2.0215
#      sourceDate   zoomLat  zoomLon
# 77   89.133843  39.60099 -8.06274]
#
#
# clusterArticles
#     sourceDate    zoomLat     zoomLon
# 73   89.399032  37.250198 -119.750298
# 79   89.433489  39.966930  -97.556099
# 80   89.489060  15.127040  101.017357
# 81   89.587915  39.966930  -97.556099
# 82   89.559283  39.966930  -97.556099
# distance data:
#       zoomLat     zoomLon
# 73  37.250198 -119.750298
# 79  39.966930  -97.556099
# 80  15.127040  101.017357
# 81  39.966930  -97.556099
# 82  39.966930  -97.556099
# temporal cluster*******************************
# [ 89.3990321  89.4334891  89.4890602  89.5879151  89.5592832]
# spatial/temporal cluster***********************
# [     sourceDate    zoomLat     zoomLon
# 73   89.399032  37.250198 -119.750298
#      sourceDate   zoomLat    zoomLon
# 79   89.433489  39.96693 -97.556099
# 81   89.587915  39.96693 -97.556099
# 82   89.559283  39.96693 -97.556099
#      sourceDate   zoomLat     zoomLon
# 80    89.48906  15.12704  101.017357]
#
#
# clusterArticles
#     sourceDate    zoomLat     zoomLon
# 83   89.993856  39.966930  -97.556099
# 84   90.054660  48.015991   66.657822
# 87   90.226640  55.002800  -96.987396
# 88   90.235523  41.465050   74.555603
# 89   90.233480  45.690800   39.830898
# 90   90.235694  38.528179   71.042000
# 91   90.232842  38.528179   71.042000
# 92   90.109768  61.946140   93.577690
# 93   90.120482  48.015991   66.657822
# 94   90.120858  48.015991   66.657822
# 95   90.240994 -23.322100  143.964798
# 96   90.250131 -23.322100  143.964798
# 97   90.129585  48.015991   66.657822
# 98   90.154995  47.487499 -100.019600
# 99   90.155042  45.690800   39.830898
# distance data:
#       zoomLat     zoomLon
# 83  39.966930  -97.556099
# 84  48.015991   66.657822
# 87  55.002800  -96.987396
# 88  41.465050   74.555603
# 89  45.690800   39.830898
# 90  38.528179   71.042000
# 91  38.528179   71.042000
# 92  61.946140   93.577690
# 93  48.015991   66.657822
# 94  48.015991   66.657822
# 95 -23.322100  143.964798
# 96 -23.322100  143.964798
# 97  48.015991   66.657822
# 98  47.487499 -100.019600
# 99  45.690800   39.830898
# temporal cluster*******************************
# [ 89.9938557  90.05466    90.2266399  90.2355229  90.2334798  90.235694
#   90.2328421  90.1097684  90.1204821  90.1208579  90.2409943  90.2501308
#   90.1295851  90.1549945  90.1550424]
# spatial/temporal cluster***********************
# [    sourceDate   zoomLat    zoomLon
# 83   89.993856  39.96693 -97.556099
#      sourceDate    zoomLat    zoomLon
# 84   90.054660  48.015991  66.657822
# 93   90.120482  48.015991  66.657822
# 94   90.120858  48.015991  66.657822
# 97   90.129585  48.015991  66.657822
#      sourceDate  zoomLat    zoomLon
# 87    90.22664  55.0028 -96.987396
#      sourceDate   zoomLat    zoomLon
# 88   90.235523  41.46505  74.555603
#      sourceDate  zoomLat    zoomLon
# 89   90.233480  45.6908  39.830898
# 99   90.155042  45.6908  39.830898
#      sourceDate    zoomLat  zoomLon
# 90   90.235694  38.528179   71.042
# 91   90.232842  38.528179   71.042
#      sourceDate   zoomLat   zoomLon
# 92   90.109768  61.94614  93.57769
#      sourceDate  zoomLat     zoomLon
# 95   90.240994 -23.3221  143.964798
# 96   90.250131 -23.3221  143.964798
#      sourceDate    zoomLat   zoomLon
# 98   90.154995  47.487499 -100.0196]
#
#
# clusterArticles
#     sourceDate    zoomLat    zoomLon
# 85   89.709469  39.966930 -97.556099
# 86   89.731974  54.470001  -2.021500
# distance data:
#       zoomLat    zoomLon
# 85  39.966930 -97.556099
# 86  54.470001  -2.021500
# temporal cluster*******************************
# [ 89.709469   89.7319741]
# spatial/temporal cluster***********************
# [    sourceDate   zoomLat    zoomLon
# 85   89.709469  39.96693 -97.556099
#      sourceDate    zoomLat  zoomLon
# 86   89.731974  54.470001  -2.0215]

# %% [markdown]
# # Questions:
# What would be the next steps?  How do we determine which cluster future articles fall into?  Do I just re-run this with all the data?
